# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("FinanaceDetails.csv")  # Replace with your actual file name

# %%
df.head()  # Shows the first 5 rows
# Out:
#   Company Fiscal Year End Date  Total Revenue  Net Income  Total Assets  \
# 0   Apple   September 30, 2023         383.30       97.00        352.60
# 1   Apple   September 24, 2022         394.30       99.80        352.80
# 2   Apple   September 25, 2021         365.80       94.70        351.00
# 3   Tesla    December 31, 2023          96.77       15.00        106.62
# 4   Tesla    December 31, 2022          81.46       12.56         82.34
#
#    Total Liabilities  Operating Cash Flow
# 0             290.40               110.50
# 1             302.10               122.20
# 2             287.90               104.00
# 3              36.40                13.26
# 4              34.32                14.72

# %%
df['Revenue Growth (%)'] = df.groupby('Company')['Total Revenue'].pct_change() * 100
df['Net Income Growth (%)'] = df.groupby('Company')['Net Income'].pct_change() * 100

# %%
plt.figure(figsize=(10, 5))
for company in df['Company'].unique():
    subset = df[df['Company'] == company]
    plt.plot(subset['Fiscal Year End Date'], subset['Total Revenue'], marker='o', label=company)

plt.xlabel("Year")
plt.ylabel("Total Revenue ($B)")
plt.title("Revenue Trend of Apple, Tesla, and Microsoft")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **Financial Summary (2022–2024)**
#
# **Apple**
# - **Revenue**: Fluctuated slightly — $394B (2022), $383B (2023), $391B (2024).
# - **Net Income**: Declined steadily — $99.8B → $93.7B.
# - **Trend**: Stable performance with minor dips.
#
# **Tesla**
# - **Revenue**: Strong growth — $81.5B → $97.7B.
# - **Net Income**: Rose in 2023, then dipped in 2024 — $5.5B → $7.5B → $7.1B.
# - **Trend**: Growing revenue but profit under slight pressure.
#
# **Microsoft**
# - **Revenue**: Consistent growth — $198.3B → $245.1B.
# - **Assets**: Healthy cash reserves and a solid balance sheet.
# - **Trend**: Strong and steady financial growth.
